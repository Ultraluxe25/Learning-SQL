# %% [markdown]
# ![image.png](attachment:d141d66e-1a73-42bf-bc8a-39f1952b96bf.png)

# %% [markdown]
# ![image.png](attachment:d98b574b-459a-45d1-8535-924098da26d1.png)

# %% [markdown]
# ![image.png](attachment:a0c4a830-1c60-44d8-8fa5-366ad74c4af2.png)

# %% [markdown]
# ![image.png](attachment:2d80c17d-aacf-4a18-8ae5-85309d5bb765.png)

# %% [markdown]
# ![image.png](attachment:d2a3a9b6-1b63-4e40-a9c1-07699bd7e3ba.png)

# %% [markdown]
# ![image.png](attachment:ab034d1f-89c7-4111-b9cb-18ac6d16a6d7.png)
# ![image.png](attachment:67722af5-cee9-4e36-944b-77ce3ba46180.png)

# %% [markdown]
# ![image.png](attachment:882dcd08-e199-4fb6-a42f-40984fd40b6f.png)

# %% [markdown]
# ![image.png](attachment:77ecec5d-9984-4632-a2bd-70695c771e8c.png)
