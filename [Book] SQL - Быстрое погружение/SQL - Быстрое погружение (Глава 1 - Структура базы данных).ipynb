# %% [markdown]
# ![image.png](attachment:3611304e-cca0-42fb-9e5b-915c0bc51ca8.png)

# %% [markdown]
# ![image.png](attachment:34a313da-776c-43fb-87f7-3780252806f3.png)

# %% [markdown]
# ### За одну минуту на YouTube загружается более 300 часов видеоконтента

# %% [markdown]
# ![image.png](attachment:2c325d21-ab92-4120-b524-33f155b6ef6f.png)

# %% [markdown]
# ### Хотя объем генерируемых данных удивляет сам по себе, еще более поразительно, что мы только начинаем их использовать. Анализу подвергается не более полупроцента от всех собираемых данных.

# %% [markdown]
# ### SQL — это основной аналитический инструмент, используемый для расшифровки больших данных, поэтому и возникла огромная потребность в специалистах, знающих язык программирования SQL. Язык данных — это язык, который в той или иной степени считается основой каждой современной технологически ориентированной компании.

# %% [markdown]
# ### В процессе учебы я понял следующее: нужно больше практики, чтобы стать отличным специалистом в области баз данных.

# %% [markdown]
# ### Никогда не упускайте из виду тот факт, что информационные технологии — самая динамично развивающаяся сфера. Изучая языки программирования, вы развиваете востребованный навык, который позволит радикально изменить мир.

# %% [markdown]
# ### Data Scientist. Он должен уметь извлекать необходимую информацию из самых разнообразных источников, видеть логические связи в системе собранной информации и на основе количественного анализа разрабатывать эффективные бизнес-решения.

# %% [markdown]
# # В быстроразвивающейся области данных, SQL — основной язык, и изучение этого языка программирования — ваш ключ к успеху в области больших данных.

# %% [markdown]
# ### База данных, как правило, изображается графически в виде цилиндров, расположенных один над другим, что символизирует несколько жестких дисков, используемых при создании центра хранения данных большой емкости.

# %% [markdown]
# ![image.png](attachment:a5aa175d-92c0-4f5c-bbd9-2827206adda0.png)

# %% [markdown]
# ![image.png](attachment:6be39d26-0997-4eec-8c9c-a0ba7b404c8d.png)

# %% [markdown]
# ### Реляционная база данных — это конструкция базы данных, которая в 1969 году была официально утверждена ученым из IBM Эдгаром Франком Коддом. В следующем году Кодд опубликовал статью под названием «Реляционная модель данных для больших, совместно используемых банков данных». Девять лет спустя несколько крупных игроков в сфере технологий, в том числе IBM и Relational Software Inc. (позже ставшая Oracle), начали использовать реляционные базы данных в коммерческих целях. Четыре десятилетия спустя реляционная модель становится наиболее распространенной формой проектирования баз данных.

# %% [markdown]
# ### Таблицы связаны друг с другом с помощью ключевых полей.

# %% [markdown]
# ### Каждая таблица в реляционной базе данных должна содержать первичный ключ.

# %% [markdown]
# ### Первичный ключ — это уникальный идентификатор записи в таблице.

# %% [markdown]
# ### Первичный ключ каждой записи должен быть уникальным и не должен быть нулевым (пустым).

# %% [markdown]
# ### Внешний ключ — это поле в таблице, значение которого соответствует первичному ключу в другой таблице.

# %% [markdown]
# ![image.png](attachment:e0d47b14-7b4c-483b-b7f0-105482c0c639.png)

# %% [markdown]
# ### Таблица **order_details** имеет два первичных ключа (обозначено значками ключей). Можно трактовать это как **составной ключ**, то есть для определения первичного ключа используются два или более поля. Хотя технически в примере задействовано два ключа, стоит рассматривать их как единый элемент — собственно первичный ключ.

# %% [markdown]
# ![image.png](attachment:4a90065c-838f-4e39-b66e-a1c20d47c641.png)

# %% [markdown]
# ### В связи «один-ко-многим» стандартный первичный ключ находится на стороне «один».

# %% [markdown]
# ![image.png](attachment:22c9c84c-588f-4627-a086-695c9d973f4e.png)

# %% [markdown]
# ![image.png](attachment:493af209-99b6-4a5b-9da2-4c59556767f4.png)

# %% [markdown]
# ### Тот факт, что мы сообщаем РСУБД, какую информацию нам предоставлять, определяет SQL как декларативный язык программирования.

# %% [markdown]
# ![image.png](attachment:46ba5b91-484a-4065-9c2a-867e07503561.png)

# %% [markdown]
# ### Различия между РСУБД обычно весьма незначительны. Если выражать в процентах, то эти различия составляют менее 10%

# %% [markdown]
# ![image.png](attachment:ffd17b3f-d67c-40ae-81e7-6fde57d9bdea.png)
